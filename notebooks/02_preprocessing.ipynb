# %%
import pandas as pd
import sys, warnings

warnings.filterwarnings('ignore', category=UserWarning)

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
raw_data = pd.read_csv('../data/raw/data.dsv', sep=';')

# %%
sys.path.append('../src')

from data_pipeline import cleaning_fe_pipeline

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5320605 entries, 0 to 5320604
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ANNEE               float64
#  1   MOIS                float64
#  2   ID                  int64
#  3   NUM_REGISTRO        int64
#  4   DATE_DOMICILIATION  object
#  5   DATE_ENREG_DO       object
#  6   DEVISE              object
#  7   FRET                float64
#  8   FOB                 float64
#  9   ASSURANCE           float64
#  10  FRAIS_ACCESSOIRE    float64
#  11  CODE_SH             int64
#  12  QUANTITE_DOMICILE   float64
#  13  DATE_IMPUTATION     object
#  14  DATE_ENREG_IMP      object
#  15  QTE_IMPUTE          float64
# dtypes: float64(8), int64(3), object(5)
# memory usage: 649.5+ MB

# %%
raw_data_sample = raw_data.head(100000)
processed_sample = cleaning_fe_pipeline.fit_transform(raw_data_sample)
processed_sample.describe()
# Out:
# [_drop_unnecessary_columns] exécuté en 0.005s | Lignes restantes: 100000
# [_filter_valid_currencies] exécuté en 0.018s | Lignes restantes: 97269
# [_set_datatypes] exécuté en 9.093s | Lignes restantes: 97269
# [_clean_quantities] exécuté en 0.173s | Lignes restantes: 97269
# [_filter_quantity] exécuté en 0.015s | Lignes restantes: 86394
# [_clean_null_date] exécuté en 0.015s | Lignes restantes: 86393
# [_optimize_memory] exécuté en 0.008s | Lignes restantes: 86393
# [_delai_extracting] exécuté en 0.013s | Lignes restantes: 62700
# [_strategic_grouping] exécuté en 0.001s | Lignes restantes: 62700
# [_temporal_engineering] exécuté en 0.004s | Lignes restantes: 62700
# [_flags_creation] exécuté en 0.002s | Lignes restantes: 62700
# [_unify_currency_to_eur] exécuté en 0.014s | Lignes restantes: 62700
#             ANNEE        MOIS           FRET             FOB    ASSURANCE  \
# count 62700.00000 62700.00000    62700.00000     62700.00000  62700.00000
# ...

# %%
processed_data = cleaning_fe_pipeline.fit_transform(raw_data)
# Out:
# [_drop_unnecessary_columns] exécuté en 0.223s | Lignes restantes: 5320605
# [_filter_valid_currencies] exécuté en 0.709s | Lignes restantes: 5175529
# [_set_datatypes] exécuté en 582.154s | Lignes restantes: 5175529
# [_clean_quantities] exécuté en 9.720s | Lignes restantes: 5175529
# [_filter_quantity] exécuté en 0.899s | Lignes restantes: 4597990
# [_clean_null_date] exécuté en 0.827s | Lignes restantes: 4597966
# [_optimize_memory] exécuté en 0.303s | Lignes restantes: 4597966
# [_delai_extracting] exécuté en 0.773s | Lignes restantes: 3332655
# [_strategic_grouping] exécuté en 0.043s | Lignes restantes: 3332655
# [_temporal_engineering] exécuté en 0.307s | Lignes restantes: 3332655
# [_flags_creation] exécuté en 0.027s | Lignes restantes: 3332655
# [_unify_currency_to_eur] exécuté en 0.796s | Lignes restantes: 3332655

# %%
processed_data.describe()
# Out:
#               ANNEE          MOIS           FRET             FOB  \
# count 3332655.00000 3332655.00000  3332655.00000   3332655.00000
# mean     2019.17331       6.60138    14300.64355    314167.12500
# std         2.46756       3.48522   251101.28125   3656671.00000
# min      2014.00000       1.00000        0.00000         0.00000
# 25%      2017.00000       4.00000        0.00000      4410.00000
# 50%      2019.00000       7.00000       33.93200     15541.40039
# 75%      2021.00000      10.00000     1342.00000     44998.81445
# max      2024.00000      12.00000 14953148.00000 203891120.00000
#
#           ASSURANCE  FRAIS_ACCESSOIRE  QUANTITE_DOMICILE     QTE_IMPUTE  \
# count 3332653.00000     3332655.00000      3332655.00000  3332655.00000
# mean       75.76111           1.68909       131958.04688    58199.90625
# std      5027.88721         300.22324       904881.12500   545283.56250
# min         0.00000           0.00000            0.00100        0.00100
# ...

# %%
output_path = '../data/processed/cleaned_data.csv'
processed_data.to_csv(output_path, index=False, sep=',')

print(f"Données traitées et exportées avec succès vers : {output_path}")
# Out:
# Données traitées et exportées avec succès vers : ../data/processed/cleaned_data.csv
